# %%
import librosa
import librosa
from matplotlib import pyplot as plt
import librosa.display
from scipy.fft import rfft,irfft, rfftfreq
import numpy as np
import wave
import pandas as pd
import sys
import matplotlib.pyplot as plt
import librosa
import IPython.display as ipd
from IPython.display import Audio
import scipy.io.wavfile
import scipy.signal
from scipy.io.wavfile import write
from scipy.io import wavfile

# %%
#import librosa

#y, sampling_rate = librosa.load('4_b.wav', )
#y_third = librosa.effects.pitch_shift(y, sr=sampling_rate, n_steps=4)

# %%
#ipd.Audio("4_b.wav")

# %%
#y_tritone = librosa.effects.pitch_shift(y, sr=sampling_rate, n_steps=-6)

# %%
#write("you1.wav",sampling_rate, y_tritone.astype(np.int16))
#ipd.Audio("you1.wav")

# %%
#y_three_qt = librosa.effects.pitch_shift(y, sr=sampling_rate, n_steps=3,
#                                        bins_per_octave=24)

# %%
#write("you.wav",sampling_rate, y_three_qt.astype(np.int16))
#ipd.Audio("you.wav")

# %%
import librosa
import soundfile


y, sr = librosa.load("g_sentence.wav")
freq= rfftfreq(len(y),1/sr)

# %%
plt.figure(figsize=(12, 4))
#plt.plot(y,freq)
librosa.display.waveshow(y, sr=sr)

# %%
steps = 13.0
#10
#13

# %%
new_y = librosa.effects.pitch_shift(y, sr, steps)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6384\2858702270.py:1: FutureWarning: Pass sr=22050, n_steps=13.0 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   new_y = librosa.effects.pitch_shift(y, sr, steps)

# %%
plt.figure(figsize=(12, 4))

freq2= rfftfreq(len(new_y),1/sr)
librosa.display.waveshow(new_y, sr=sr)

# %%
soundfile.write("pitchShifted.wav", new_y, sr)
